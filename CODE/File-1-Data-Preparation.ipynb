# %% [markdown]
# ![File-1-Google-Play.png](attachment:File-1-Google-Play.png)

# %% [markdown]
# <div style="text-align: center; background-color: #856ff8; padding: 10px;">
#     <h2 style="font-weight: bold;">OUTLINE</h2>
# </div>

# %% [markdown]
# - Importing Various Modules
# - Loading Dataset
# - Data Wrangling
#     - Computing the size of DataFrame
#     - Summary Statistics for Numerical Columns
#     - Generating Basic Information of Attributes
#     - Handling Columns
# - Save Dataframe to CSV File

# %% [markdown]
# <div style="text-align: center; background-color: yellow; padding: 10px;">
#     <h2 style="font-weight: bold;">IMPORTING VARIOUS MODULES</h2>
# </div>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings

warnings.filterwarnings("ignore")

# %matplotlib inline

# %% [markdown]
# <div style="text-align: center; background-color: yellow; padding: 10px;">
#     <h2 style="font-weight: bold;">LOADING DATASET</h2>
# </div>

# %%
apps_data = pd.read_csv(r'file1_googleplaystore.csv')

# %%
# Print top 5 rows in the dataframe.
apps_data.head().style.set_properties(**{'background-color': '#E9F6E2','color': 'black','border-color': '#8b8c8c'})
# Out:
# <style type="text/css">
# #T_0fa20_row0_col0, #T_0fa20_row0_col1, #T_0fa20_row0_col2, #T_0fa20_row0_col3, #T_0fa20_row0_col4, #T_0fa20_row0_col5, #T_0fa20_row0_col6, #T_0fa20_row0_col7, #T_0fa20_row0_col8, #T_0fa20_row0_col9, #T_0fa20_row0_col10, #T_0fa20_row0_col11, #T_0fa20_row0_col12, #T_0fa20_row1_col0, #T_0fa20_row1_col1, #T_0fa20_row1_col2, #T_0fa20_row1_col3, #T_0fa20_row1_col4, #T_0fa20_row1_col5, #T_0fa20_row1_col6, #T_0fa20_row1_col7, #T_0fa20_row1_col8, #T_0fa20_row1_col9, #T_0fa20_row1_col10, #T_0fa20_row1_col11, #T_0fa20_row1_col12, #T_0fa20_row2_col0, #T_0fa20_row2_col1, #T_0fa20_row2_col2, #T_0fa20_row2_col3, #T_0fa20_row2_col4, #T_0fa20_row2_col5, #T_0fa20_row2_col6, #T_0fa20_row2_col7, #T_0fa20_row2_col8, #T_0fa20_row2_col9, #T_0fa20_row2_col10, #T_0fa20_row2_col11, #T_0fa20_row2_col12, #T_0fa20_row3_col0, #T_0fa20_row3_col1, #T_0fa20_row3_col2, #T_0fa20_row3_col3, #T_0fa20_row3_col4, #T_0fa20_row3_col5, #T_0fa20_row3_col6, #T_0fa20_row3_col7, #T_0fa20_row3_col8, #T_0fa20_row3_col9, #T_0fa20_row3_col10, #T_0fa20_row3_col11, #T_0fa20_row3_col12, #T_0fa20_row4_col0, #T_0fa20_row4_col1, #T_0fa20_row4_col2, #T_0fa20_row4_col3, #T_0fa20_row4_col4, #T_0fa20_row4_col5, #T_0fa20_row4_col6, #T_0fa20_row4_col7, #T_0fa20_row4_col8, #T_0fa20_row4_col9, #T_0fa20_row4_col10, #T_0fa20_row4_col11, #T_0fa20_row4_col12 {
#   background-color: #E9F6E2;
#   color: black;
#   border-color: #8b8c8c;
# }
# </style>
# <table id="T_0fa20">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0fa20_level0_col0" class="col_heading level0 col0" >App</th>
#       <th id="T_0fa20_level0_col1" class="col_heading level0 col1" >Category</th>
#       <th id="T_0fa20_level0_col2" class="col_heading level0 col2" >Rating</th>
#       <th id="T_0fa20_level0_col3" class="col_heading level0 col3" >Reviews</th>
#       <th id="T_0fa20_level0_col4" class="col_heading level0 col4" >Size</th>
#       <th id="T_0fa20_level0_col5" class="col_heading level0 col5" >Installs</th>
#       <th id="T_0fa20_level0_col6" class="col_heading level0 col6" >Type</th>
#       <th id="T_0fa20_level0_col7" class="col_heading level0 col7" >Price</th>
#       <th id="T_0fa20_level0_col8" class="col_heading level0 col8" >Content Rating</th>
#       <th id="T_0fa20_level0_col9" class="col_heading level0 col9" >Genres</th>
#       <th id="T_0fa20_level0_col10" class="col_heading level0 col10" >Last Updated</th>
#       <th id="T_0fa20_level0_col11" class="col_heading level0 col11" >Current Ver</th>
#       <th id="T_0fa20_level0_col12" class="col_heading level0 col12" >Android Ver</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0fa20_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_0fa20_row0_col0" class="data row0 col0" >Photo Editor & Candy Camera & Grid & ScrapBook</td>
#       <td id="T_0fa20_row0_col1" class="data row0 col1" >ART_AND_DESIGN</td>
#       <td id="T_0fa20_row0_col2" class="data row0 col2" >4.100000</td>
#       <td id="T_0fa20_row0_col3" class="data row0 col3" >159</td>
#       <td id="T_0fa20_row0_col4" class="data row0 col4" >19M</td>
#       <td id="T_0fa20_row0_col5" class="data row0 col5" >10,000+</td>
#       <td id="T_0fa20_row0_col6" class="data row0 col6" >Free</td>
#       <td id="T_0fa20_row0_col7" class="data row0 col7" >0</td>
#       <td id="T_0fa20_row0_col8" class="data row0 col8" >Everyone</td>
#       <td id="T_0fa20_row0_col9" class="data row0 col9" >Art & Design</td>
#       <td id="T_0fa20_row0_col10" class="data row0 col10" >January 7, 2018</td>
#       <td id="T_0fa20_row0_col11" class="data row0 col11" >1.0.0</td>
#       <td id="T_0fa20_row0_col12" class="data row0 col12" >4.0.3 and up</td>
#     </tr>
#     <tr>
#       <th id="T_0fa20_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_0fa20_row1_col0" class="data row1 col0" >Coloring book moana</td>
#       <td id="T_0fa20_row1_col1" class="data row1 col1" >ART_AND_DESIGN</td>
#       <td id="T_0fa20_row1_col2" class="data row1 col2" >3.900000</td>
#       <td id="T_0fa20_row1_col3" class="data row1 col3" >967</td>
#       <td id="T_0fa20_row1_col4" class="data row1 col4" >14M</td>
#       <td id="T_0fa20_row1_col5" class="data row1 col5" >500,000+</td>
#       <td id="T_0fa20_row1_col6" class="data row1 col6" >Free</td>
#       <td id="T_0fa20_row1_col7" class="data row1 col7" >0</td>
#       <td id="T_0fa20_row1_col8" class="data row1 col8" >Everyone</td>
#       <td id="T_0fa20_row1_col9" class="data row1 col9" >Art & Design;Pretend Play</td>
#       <td id="T_0fa20_row1_col10" class="data row1 col10" >January 15, 2018</td>
#       <td id="T_0fa20_row1_col11" class="data row1 col11" >2.0.0</td>
#       <td id="T_0fa20_row1_col12" class="data row1 col12" >4.0.3 and up</td>
#     </tr>
#     <tr>
#       <th id="T_0fa20_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_0fa20_row2_col0" class="data row2 col0" >U Launcher Lite – FREE Live Cool Themes, Hide Apps</td>
#       <td id="T_0fa20_row2_col1" class="data row2 col1" >ART_AND_DESIGN</td>
#       <td id="T_0fa20_row2_col2" class="data row2 col2" >4.700000</td>
#       <td id="T_0fa20_row2_col3" class="data row2 col3" >87510</td>
#       <td id="T_0fa20_row2_col4" class="data row2 col4" >8.7M</td>
#       <td id="T_0fa20_row2_col5" class="data row2 col5" >5,000,000+</td>
#       <td id="T_0fa20_row2_col6" class="data row2 col6" >Free</td>
#       <td id="T_0fa20_row2_col7" class="data row2 col7" >0</td>
#       <td id="T_0fa20_row2_col8" class="data row2 col8" >Everyone</td>
#       <td id="T_0fa20_row2_col9" class="data row2 col9" >Art & Design</td>
#       <td id="T_0fa20_row2_col10" class="data row2 col10" >August 1, 2018</td>
#       <td id="T_0fa20_row2_col11" class="data row2 col11" >1.2.4</td>
#       <td id="T_0fa20_row2_col12" class="data row2 col12" >4.0.3 and up</td>
#     </tr>
#     <tr>
#       <th id="T_0fa20_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_0fa20_row3_col0" class="data row3 col0" >Sketch - Draw & Paint</td>
#       <td id="T_0fa20_row3_col1" class="data row3 col1" >ART_AND_DESIGN</td>
#       <td id="T_0fa20_row3_col2" class="data row3 col2" >4.500000</td>
#       <td id="T_0fa20_row3_col3" class="data row3 col3" >215644</td>
#       <td id="T_0fa20_row3_col4" class="data row3 col4" >25M</td>
#       <td id="T_0fa20_row3_col5" class="data row3 col5" >50,000,000+</td>
#       <td id="T_0fa20_row3_col6" class="data row3 col6" >Free</td>
#       <td id="T_0fa20_row3_col7" class="data row3 col7" >0</td>
#       <td id="T_0fa20_row3_col8" class="data row3 col8" >Teen</td>
#       <td id="T_0fa20_row3_col9" class="data row3 col9" >Art & Design</td>
#       <td id="T_0fa20_row3_col10" class="data row3 col10" >June 8, 2018</td>
#       <td id="T_0fa20_row3_col11" class="data row3 col11" >Varies with device</td>
#       <td id="T_0fa20_row3_col12" class="data row3 col12" >4.2 and up</td>
#     </tr>
#     <tr>
#       <th id="T_0fa20_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_0fa20_row4_col0" class="data row4 col0" >Pixel Draw - Number Art Coloring Book</td>
#       <td id="T_0fa20_row4_col1" class="data row4 col1" >ART_AND_DESIGN</td>
#       <td id="T_0fa20_row4_col2" class="data row4 col2" >4.300000</td>
#       <td id="T_0fa20_row4_col3" class="data row4 col3" >967</td>
#       <td id="T_0fa20_row4_col4" class="data row4 col4" >2.8M</td>
#       <td id="T_0fa20_row4_col5" class="data row4 col5" >100,000+</td>
#       <td id="T_0fa20_row4_col6" class="data row4 col6" >Free</td>
#       <td id="T_0fa20_row4_col7" class="data row4 col7" >0</td>
#       <td id="T_0fa20_row4_col8" class="data row4 col8" >Everyone</td>
#       <td id="T_0fa20_row4_col9" class="data row4 col9" >Art & Design;Creativity</td>
#       <td id="T_0fa20_row4_col10" class="data row4 col10" >June 20, 2018</td>
#       <td id="T_0fa20_row4_col11" class="data row4 col11" >1.1</td>
#       <td id="T_0fa20_row4_col12" class="data row4 col12" >4.4 and up</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Print bottom 5 rows in the dataframe.
apps_data.tail().style.set_properties(**{'background-color': '#E9F6E2','color': 'black','border-color': '#8b8c8c'})
# Out:
# <style type="text/css">
# #T_47e15_row0_col0, #T_47e15_row0_col1, #T_47e15_row0_col2, #T_47e15_row0_col3, #T_47e15_row0_col4, #T_47e15_row0_col5, #T_47e15_row0_col6, #T_47e15_row0_col7, #T_47e15_row0_col8, #T_47e15_row0_col9, #T_47e15_row0_col10, #T_47e15_row0_col11, #T_47e15_row0_col12, #T_47e15_row1_col0, #T_47e15_row1_col1, #T_47e15_row1_col2, #T_47e15_row1_col3, #T_47e15_row1_col4, #T_47e15_row1_col5, #T_47e15_row1_col6, #T_47e15_row1_col7, #T_47e15_row1_col8, #T_47e15_row1_col9, #T_47e15_row1_col10, #T_47e15_row1_col11, #T_47e15_row1_col12, #T_47e15_row2_col0, #T_47e15_row2_col1, #T_47e15_row2_col2, #T_47e15_row2_col3, #T_47e15_row2_col4, #T_47e15_row2_col5, #T_47e15_row2_col6, #T_47e15_row2_col7, #T_47e15_row2_col8, #T_47e15_row2_col9, #T_47e15_row2_col10, #T_47e15_row2_col11, #T_47e15_row2_col12, #T_47e15_row3_col0, #T_47e15_row3_col1, #T_47e15_row3_col2, #T_47e15_row3_col3, #T_47e15_row3_col4, #T_47e15_row3_col5, #T_47e15_row3_col6, #T_47e15_row3_col7, #T_47e15_row3_col8, #T_47e15_row3_col9, #T_47e15_row3_col10, #T_47e15_row3_col11, #T_47e15_row3_col12, #T_47e15_row4_col0, #T_47e15_row4_col1, #T_47e15_row4_col2, #T_47e15_row4_col3, #T_47e15_row4_col4, #T_47e15_row4_col5, #T_47e15_row4_col6, #T_47e15_row4_col7, #T_47e15_row4_col8, #T_47e15_row4_col9, #T_47e15_row4_col10, #T_47e15_row4_col11, #T_47e15_row4_col12 {
#   background-color: #E9F6E2;
#   color: black;
#   border-color: #8b8c8c;
# }
# </style>
# <table id="T_47e15">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_47e15_level0_col0" class="col_heading level0 col0" >App</th>
#       <th id="T_47e15_level0_col1" class="col_heading level0 col1" >Category</th>
#       <th id="T_47e15_level0_col2" class="col_heading level0 col2" >Rating</th>
#       <th id="T_47e15_level0_col3" class="col_heading level0 col3" >Reviews</th>
#       <th id="T_47e15_level0_col4" class="col_heading level0 col4" >Size</th>
#       <th id="T_47e15_level0_col5" class="col_heading level0 col5" >Installs</th>
#       <th id="T_47e15_level0_col6" class="col_heading level0 col6" >Type</th>
#       <th id="T_47e15_level0_col7" class="col_heading level0 col7" >Price</th>
#       <th id="T_47e15_level0_col8" class="col_heading level0 col8" >Content Rating</th>
#       <th id="T_47e15_level0_col9" class="col_heading level0 col9" >Genres</th>
#       <th id="T_47e15_level0_col10" class="col_heading level0 col10" >Last Updated</th>
#       <th id="T_47e15_level0_col11" class="col_heading level0 col11" >Current Ver</th>
#       <th id="T_47e15_level0_col12" class="col_heading level0 col12" >Android Ver</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_47e15_level0_row0" class="row_heading level0 row0" >10836</th>
#       <td id="T_47e15_row0_col0" class="data row0 col0" >Sya9a Maroc - FR</td>
#       <td id="T_47e15_row0_col1" class="data row0 col1" >FAMILY</td>
#       <td id="T_47e15_row0_col2" class="data row0 col2" >4.500000</td>
#       <td id="T_47e15_row0_col3" class="data row0 col3" >38</td>
#       <td id="T_47e15_row0_col4" class="data row0 col4" >53M</td>
#       <td id="T_47e15_row0_col5" class="data row0 col5" >5,000+</td>
#       <td id="T_47e15_row0_col6" class="data row0 col6" >Free</td>
#       <td id="T_47e15_row0_col7" class="data row0 col7" >0</td>
#       <td id="T_47e15_row0_col8" class="data row0 col8" >Everyone</td>
#       <td id="T_47e15_row0_col9" class="data row0 col9" >Education</td>
#       <td id="T_47e15_row0_col10" class="data row0 col10" >July 25, 2017</td>
#       <td id="T_47e15_row0_col11" class="data row0 col11" >1.48</td>
#       <td id="T_47e15_row0_col12" class="data row0 col12" >4.1 and up</td>
#     </tr>
#     <tr>
#       <th id="T_47e15_level0_row1" class="row_heading level0 row1" >10837</th>
#       <td id="T_47e15_row1_col0" class="data row1 col0" >Fr. Mike Schmitz Audio Teachings</td>
#       <td id="T_47e15_row1_col1" class="data row1 col1" >FAMILY</td>
#       <td id="T_47e15_row1_col2" class="data row1 col2" >5.000000</td>
#       <td id="T_47e15_row1_col3" class="data row1 col3" >4</td>
#       <td id="T_47e15_row1_col4" class="data row1 col4" >3.6M</td>
#       <td id="T_47e15_row1_col5" class="data row1 col5" >100+</td>
#       <td id="T_47e15_row1_col6" class="data row1 col6" >Free</td>
#       <td id="T_47e15_row1_col7" class="data row1 col7" >0</td>
#       <td id="T_47e15_row1_col8" class="data row1 col8" >Everyone</td>
#       <td id="T_47e15_row1_col9" class="data row1 col9" >Education</td>
#       <td id="T_47e15_row1_col10" class="data row1 col10" >July 6, 2018</td>
#       <td id="T_47e15_row1_col11" class="data row1 col11" >1.0</td>
#       <td id="T_47e15_row1_col12" class="data row1 col12" >4.1 and up</td>
#     </tr>
#     <tr>
#       <th id="T_47e15_level0_row2" class="row_heading level0 row2" >10838</th>
#       <td id="T_47e15_row2_col0" class="data row2 col0" >Parkinson Exercices FR</td>
#       <td id="T_47e15_row2_col1" class="data row2 col1" >MEDICAL</td>
#       <td id="T_47e15_row2_col2" class="data row2 col2" >nan</td>
#       <td id="T_47e15_row2_col3" class="data row2 col3" >3</td>
#       <td id="T_47e15_row2_col4" class="data row2 col4" >9.5M</td>
#       <td id="T_47e15_row2_col5" class="data row2 col5" >1,000+</td>
#       <td id="T_47e15_row2_col6" class="data row2 col6" >Free</td>
#       <td id="T_47e15_row2_col7" class="data row2 col7" >0</td>
#       <td id="T_47e15_row2_col8" class="data row2 col8" >Everyone</td>
#       <td id="T_47e15_row2_col9" class="data row2 col9" >Medical</td>
#       <td id="T_47e15_row2_col10" class="data row2 col10" >January 20, 2017</td>
#       <td id="T_47e15_row2_col11" class="data row2 col11" >1.0</td>
#       <td id="T_47e15_row2_col12" class="data row2 col12" >2.2 and up</td>
#     </tr>
#     <tr>
#       <th id="T_47e15_level0_row3" class="row_heading level0 row3" >10839</th>
#       <td id="T_47e15_row3_col0" class="data row3 col0" >The SCP Foundation DB fr nn5n</td>
#       <td id="T_47e15_row3_col1" class="data row3 col1" >BOOKS_AND_REFERENCE</td>
#       <td id="T_47e15_row3_col2" class="data row3 col2" >4.500000</td>
#       <td id="T_47e15_row3_col3" class="data row3 col3" >114</td>
#       <td id="T_47e15_row3_col4" class="data row3 col4" >Varies with device</td>
#       <td id="T_47e15_row3_col5" class="data row3 col5" >1,000+</td>
#       <td id="T_47e15_row3_col6" class="data row3 col6" >Free</td>
#       <td id="T_47e15_row3_col7" class="data row3 col7" >0</td>
#       <td id="T_47e15_row3_col8" class="data row3 col8" >Mature 17+</td>
#       <td id="T_47e15_row3_col9" class="data row3 col9" >Books & Reference</td>
#       <td id="T_47e15_row3_col10" class="data row3 col10" >January 19, 2015</td>
#       <td id="T_47e15_row3_col11" class="data row3 col11" >Varies with device</td>
#       <td id="T_47e15_row3_col12" class="data row3 col12" >Varies with device</td>
#     </tr>
#     <tr>
#       <th id="T_47e15_level0_row4" class="row_heading level0 row4" >10840</th>
#       <td id="T_47e15_row4_col0" class="data row4 col0" >iHoroscope - 2018 Daily Horoscope & Astrology</td>
#       <td id="T_47e15_row4_col1" class="data row4 col1" >LIFESTYLE</td>
#       <td id="T_47e15_row4_col2" class="data row4 col2" >4.500000</td>
#       <td id="T_47e15_row4_col3" class="data row4 col3" >398307</td>
#       <td id="T_47e15_row4_col4" class="data row4 col4" >19M</td>
#       <td id="T_47e15_row4_col5" class="data row4 col5" >10,000,000+</td>
#       <td id="T_47e15_row4_col6" class="data row4 col6" >Free</td>
#       <td id="T_47e15_row4_col7" class="data row4 col7" >0</td>
#       <td id="T_47e15_row4_col8" class="data row4 col8" >Everyone</td>
#       <td id="T_47e15_row4_col9" class="data row4 col9" >Lifestyle</td>
#       <td id="T_47e15_row4_col10" class="data row4 col10" >July 25, 2018</td>
#       <td id="T_47e15_row4_col11" class="data row4 col11" >Varies with device</td>
#       <td id="T_47e15_row4_col12" class="data row4 col12" >Varies with device</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# <div style="text-align: center; background-color: yellow; padding: 10px;">
#     <h2 style="font-weight: bold;">DATA WRANGLING</h2>
# </div>

# %% [markdown]
# ## <span style='color:black'> 1] COMPUTING SIZE OF DATASET </span>

# %%
# Print the shape of the DataFrame
print("The shape of data frame:", apps_data.shape)
# Print the length (number of rows) of the DataFrame
print("Number of Rows in the dataframe:", len(apps_data))
# Print the number of columns in the DataFrame
print("Number of Columns in the dataframe:", len(apps_data.columns))
# Out:
# The shape of data frame: (10841, 13)
# Number of Rows in the dataframe: 10841
# Number of Columns in the dataframe: 13

# %% [markdown]
# ## 2] SUMMARY STATISTICS FOR NUMERICAL COLUMNS

# %%
apps_data.describe(include='all')
# Out:
#            App Category       Rating Reviews                Size    Installs  \
# count    10841    10841  9367.000000   10841               10841       10841
# unique    9660       34          NaN    6002                 462          22
# top     ROBLOX   FAMILY          NaN       0  Varies with device  1,000,000+
# freq         9     1972          NaN     596                1695        1579
# mean       NaN      NaN     4.193338     NaN                 NaN         NaN
# std        NaN      NaN     0.537431     NaN                 NaN         NaN
# min        NaN      NaN     1.000000     NaN                 NaN         NaN
# 25%        NaN      NaN     4.000000     NaN                 NaN         NaN
# 50%        NaN      NaN     4.300000     NaN                 NaN         NaN
# 75%        NaN      NaN     4.500000     NaN                 NaN         NaN
# max        NaN      NaN    19.000000     NaN                 NaN         NaN
#
#          Type  Price Content Rating Genres    Last Updated  \
# count   10840  10841          10840  10841           10841
# unique      3     93              6    120            1378
# top      Free      0       Everyone  Tools  August 3, 2018
# freq    10039  10040           8714    842             326
# mean      NaN    NaN            NaN    NaN             NaN
# std       NaN    NaN            NaN    NaN             NaN
# min       NaN    NaN            NaN    NaN             NaN
# 25%       NaN    NaN            NaN    NaN             NaN
# 50%       NaN    NaN            NaN    NaN             NaN
# 75%       NaN    NaN            NaN    NaN             NaN
# max       NaN    NaN            NaN    NaN             NaN
#
#                Current Ver Android Ver
# count                10833       10838
# unique                2832          33
# top     Varies with device  4.1 and up
# freq                  1459        2451
# mean                   NaN         NaN
# std                    NaN         NaN
# min                    NaN         NaN
# 25%                    NaN         NaN
# 50%                    NaN         NaN
# 75%                    NaN         NaN
# max                    NaN         NaN

# %% [markdown]
# ### Summary of the dataset
#
# - The described method will help to see how data has been spread for numerical values.
# - We can clearly see the minimum value, mean values, different percentile values, and maximum values.

# %% [markdown]
# ## 3] GENERATING BASIC INFORMATION OF ATTRIBUTES

# %%
apps_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10841 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10841 non-null  object
#  1   Category        10841 non-null  object
#  2   Rating          9367 non-null   float64
#  3   Reviews         10841 non-null  object
#  4   Size            10841 non-null  object
#  5   Installs        10841 non-null  object
#  6   Type            10840 non-null  object
#  7   Price           10841 non-null  object
#  8   Content Rating  10840 non-null  object
#  9   Genres          10841 non-null  object
#  10  Last Updated    10841 non-null  object
#  11  Current Ver     10833 non-null  object
#  12  Android Ver     10838 non-null  object
# dtypes: float64(1), object(12)
# memory usage: 1.1+ MB

# %% [markdown]
# ### Insights
#
# - The data has 12 object and 1 numeric feature
# - We need to convert (Reviews & Size & Installs & Price) to int
# - We need to Change Last update into a datetime column

# %% [markdown]
# ## 4] HANDLING COLUMNS

# %% [markdown]
# ### 4.1] Reviews

# %%
# Calculate the number of rows in the 'Reviews' column where the values are numeric.
apps_data.Reviews.str.isnumeric().sum()
# Out:
# 10840

# %%
# Create a DataFrame containing rows with non-numeric values in the 'Reviews' column.
apps_data[~apps_data['Reviews'].str.isnumeric()]
# Out:
#                                            App Category  Rating Reviews  \
# 10472  Life Made WI-Fi Touchscreen Photo Frame      1.9    19.0    3.0M
#
#          Size Installs Type     Price Content Rating             Genres  \
# 10472  1,000+     Free    0  Everyone            NaN  February 11, 2018
#
#       Last Updated Current Ver Android Ver
# 10472       1.0.19  4.0 and up         NaN

# %%
# Create a copy of the original DataFrame 'apps_data'.
apps_data_copy = apps_data.copy()

# %%
# Drop the row with index 10472 from 'apps_data_copy'.
apps_data_copy = apps_data_copy.drop(apps_data_copy.index[10472])

# %%
# Create a DataFrame containing rows with non-numeric values in the 'Reviews' column in 'apps_data_copy'.
apps_data_copy[~apps_data_copy['Reviews'].str.isnumeric()]
# Out:
# Empty DataFrame
# Columns: [App, Category, Rating, Reviews, Size, Installs, Type, Price, Content Rating, Genres, Last Updated, Current Ver, Android Ver]
# Index: []

# %%
# Converting Reviews datatype to int 
apps_data_copy["Reviews"] = apps_data_copy["Reviews"].astype(int)

# %% [markdown]
# ### 4.2] Size

# %%
apps_data_copy['Size'].unique()
# Out:
# array(['19M', '14M', '8.7M', '25M', '2.8M', '5.6M', '29M', '33M', '3.1M',
#        '28M', '12M', '20M', '21M', '37M', '2.7M', '5.5M', '17M', '39M',
#        '31M', '4.2M', '7.0M', '23M', '6.0M', '6.1M', '4.6M', '9.2M',
#        '5.2M', '11M', '24M', 'Varies with device', '9.4M', '15M', '10M',
#        '1.2M', '26M', '8.0M', '7.9M', '56M', '57M', '35M', '54M', '201k',
#        '3.6M', '5.7M', '8.6M', '2.4M', '27M', '2.5M', '16M', '3.4M',
#        '8.9M', '3.9M', '2.9M', '38M', '32M', '5.4M', '18M', '1.1M',
#        '2.2M', '4.5M', '9.8M', '52M', '9.0M', '6.7M', '30M', '2.6M',
#        '7.1M', '3.7M', '22M', '7.4M', '6.4M', '3.2M', '8.2M', '9.9M',
#        '4.9M', '9.5M', '5.0M', '5.9M', '13M', '73M', '6.8M', '3.5M',
#        '4.0M', '2.3M', '7.2M', '2.1M', '42M', '7.3M', '9.1M', '55M',
#        '23k', '6.5M', '1.5M', '7.5M', '51M', '41M', '48M', '8.5M', '46M',
#        '8.3M', '4.3M', '4.7M', '3.3M', '40M', '7.8M', '8.8M', '6.6M',
#        '5.1M', '61M', '66M', '79k', '8.4M', '118k', '44M', '695k', '1.6M',
#        '6.2M', '18k', '53M', '1.4M', '3.0M', '5.8M', '3.8M', '9.6M',
#        '45M', '63M', '49M', '77M', '4.4M', '4.8M', '70M', '6.9M', '9.3M',
#        '10.0M', '8.1M', '36M', '84M', '97M', '2.0M', '1.9M', '1.8M',
#        '5.3M', '47M', '556k', '526k', '76M', '7.6M', '59M', '9.7M', '78M',
#        '72M', '43M', '7.7M', '6.3M', '334k', '34M', '93M', '65M', '79M',
#        '100M', '58M', '50M', '68M', '64M', '67M', '60M', '94M', '232k',
#        '99M', '624k', '95M', '8.5k', '41k', '292k', '11k', '80M', '1.7M',
#        '74M', '62M', '69M', '75M', '98M', '85M', '82M', '96M', '87M',
#        '71M', '86M', '91M', '81M', '92M', '83M', '88M', '704k', '862k',
#        '899k', '378k', '266k', '375k', '1.3M', '975k', '980k', '4.1M',
#        '89M', '696k', '544k', '525k', '920k', '779k', '853k', '720k',
#        '713k', '772k', '318k', '58k', '241k', '196k', '857k', '51k',
#        '953k', '865k', '251k', '930k', '540k', '313k', '746k', '203k',
#        '26k', '314k', '239k', '371k', '220k', '730k', '756k', '91k',
#        '293k', '17k', '74k', '14k', '317k', '78k', '924k', '902k', '818k',
#        '81k', '939k', '169k', '45k', '475k', '965k', '90M', '545k', '61k',
#        '283k', '655k', '714k', '93k', '872k', '121k', '322k', '1.0M',
#        '976k', '172k', '238k', '549k', '206k', '954k', '444k', '717k',
#        '210k', '609k', '308k', '705k', '306k', '904k', '473k', '175k',
#        '350k', '383k', '454k', '421k', '70k', '812k', '442k', '842k',
#        '417k', '412k', '459k', '478k', '335k', '782k', '721k', '430k',
#        '429k', '192k', '200k', '460k', '728k', '496k', '816k', '414k',
#        '506k', '887k', '613k', '243k', '569k', '778k', '683k', '592k',
#        '319k', '186k', '840k', '647k', '191k', '373k', '437k', '598k',
#        '716k', '585k', '982k', '222k', '219k', '55k', '948k', '323k',
#        '691k', '511k', '951k', '963k', '25k', '554k', '351k', '27k',
#        '82k', '208k', '913k', '514k', '551k', '29k', '103k', '898k',
#        '743k', '116k', '153k', '209k', '353k', '499k', '173k', '597k',
#        '809k', '122k', '411k', '400k', '801k', '787k', '237k', '50k',
#        '643k', '986k', '97k', '516k', '837k', '780k', '961k', '269k',
#        '20k', '498k', '600k', '749k', '642k', '881k', '72k', '656k',
#        '601k', '221k', '228k', '108k', '940k', '176k', '33k', '663k',
#        '34k', '942k', '259k', '164k', '458k', '245k', '629k', '28k',
#        '288k', '775k', '785k', '636k', '916k', '994k', '309k', '485k',
#        '914k', '903k', '608k', '500k', '54k', '562k', '847k', '957k',
#        '688k', '811k', '270k', '48k', '329k', '523k', '921k', '874k',
#        '981k', '784k', '280k', '24k', '518k', '754k', '892k', '154k',
#        '860k', '364k', '387k', '626k', '161k', '879k', '39k', '970k',
#        '170k', '141k', '160k', '144k', '143k', '190k', '376k', '193k',
#        '246k', '73k', '658k', '992k', '253k', '420k', '404k', '470k',
#        '226k', '240k', '89k', '234k', '257k', '861k', '467k', '157k',
#        '44k', '676k', '67k', '552k', '885k', '1020k', '582k', '619k'],
#       dtype=object)

# %% [markdown]
# ### <font color=red>Operation:</font>
#
# ### - Remove all characters from size and convert it to float

# %%
# Data Cleaning and Transformation for the 'Size' Column
apps_data_copy['Size']=apps_data_copy['Size'].str.replace('M','000')
apps_data_copy['Size']=apps_data_copy['Size'].str.replace('k','')
apps_data_copy['Size']=apps_data_copy['Size'].replace("Varies with device",np.nan)
apps_data_copy['Size']=apps_data_copy['Size'].astype('float')

# %%
apps_data_copy['Size']
# Out:
# 0        19000.0
# 1        14000.0
# 2            8.7
# 3        25000.0
# 4            2.8
#           ...
# 10836    53000.0
# 10837        3.6
# 10838        9.5
# 10839        NaN
# 10840    19000.0
# Name: Size, Length: 10840, dtype: float64

# %% [markdown]
# ### <font color=red>Operation:</font>
#
# ### - Convert mega bytes to kilo bytes then convert all to mega bytes.

# %%
for i in apps_data_copy['Size']:
    if i < 10:
        apps_data_copy['Size']=apps_data_copy['Size'].replace(i,i*1000)
apps_data_copy['Size'] = apps_data_copy['Size']/1000
apps_data_copy['Size']
# Out:
# 0        19.0
# 1        14.0
# 2         8.7
# 3        25.0
# 4         2.8
#          ...
# 10836    53.0
# 10837     3.6
# 10838     9.5
# 10839     NaN
# 10840    19.0
# Name: Size, Length: 10840, dtype: float64

# %% [markdown]
# ### 4.3] Installs and Price

# %%
apps_data_copy['Installs'].unique()
# Out:
# array(['10,000+', '500,000+', '5,000,000+', '50,000,000+', '100,000+',
#        '50,000+', '1,000,000+', '10,000,000+', '5,000+', '100,000,000+',
#        '1,000,000,000+', '1,000+', '500,000,000+', '50+', '100+', '500+',
#        '10+', '1+', '5+', '0+', '0'], dtype=object)

# %%
apps_data_copy['Price'].unique()
# Out:
# array(['0', '$4.99', '$3.99', '$6.99', '$1.49', '$2.99', '$7.99', '$5.99',
#        '$3.49', '$1.99', '$9.99', '$7.49', '$0.99', '$9.00', '$5.49',
#        '$10.00', '$24.99', '$11.99', '$79.99', '$16.99', '$14.99',
#        '$1.00', '$29.99', '$12.99', '$2.49', '$10.99', '$1.50', '$19.99',
#        '$15.99', '$33.99', '$74.99', '$39.99', '$3.95', '$4.49', '$1.70',
#        '$8.99', '$2.00', '$3.88', '$25.99', '$399.99', '$17.99',
#        '$400.00', '$3.02', '$1.76', '$4.84', '$4.77', '$1.61', '$2.50',
#        '$1.59', '$6.49', '$1.29', '$5.00', '$13.99', '$299.99', '$379.99',
#        '$37.99', '$18.99', '$389.99', '$19.90', '$8.49', '$1.75',
#        '$14.00', '$4.85', '$46.99', '$109.99', '$154.99', '$3.08',
#        '$2.59', '$4.80', '$1.96', '$19.40', '$3.90', '$4.59', '$15.46',
#        '$3.04', '$4.29', '$2.60', '$3.28', '$4.60', '$28.99', '$2.95',
#        '$2.90', '$1.97', '$200.00', '$89.99', '$2.56', '$30.99', '$3.61',
#        '$394.99', '$1.26', '$1.20', '$1.04'], dtype=object)

# %%
# List of characters to remove from specified columns
chars_to_remove = ['+', ',', '$']

# List of columns to clean
cols_to_clean = ['Installs', 'Price']

# Iterate over each character to remove
for item in chars_to_remove:
    # Iterate over each column to clean
    for col in cols_to_clean:
        # Remove the specified character from the values in the column
        apps_data_copy[col] = apps_data_copy[col].str.replace(item, '')

# %%
apps_data_copy.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#    Reviews  Size  Installs  Type Price Content Rating  \
# 0      159  19.0     10000  Free     0       Everyone
# 1      967  14.0    500000  Free     0       Everyone
# 2    87510   8.7   5000000  Free     0       Everyone
# 3   215644  25.0  50000000  Free     0           Teen
# 4      967   2.8    100000  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# 1  Art & Design;Pretend Play  January 15, 2018               2.0.0
# 2               Art & Design    August 1, 2018               1.2.4
# 3               Art & Design      June 8, 2018  Varies with device
# 4    Art & Design;Creativity     June 20, 2018                 1.1
#
#     Android Ver
# 0  4.0.3 and up
# 1  4.0.3 and up
# 2  4.0.3 and up
# 3    4.2 and up
# 4    4.4 and up

# %%
apps_data_copy.Price.unique()
# Out:
# array(['0', '4.99', '3.99', '6.99', '1.49', '2.99', '7.99', '5.99',
#        '3.49', '1.99', '9.99', '7.49', '0.99', '9.00', '5.49', '10.00',
#        '24.99', '11.99', '79.99', '16.99', '14.99', '1.00', '29.99',
#        '12.99', '2.49', '10.99', '1.50', '19.99', '15.99', '33.99',
#        '74.99', '39.99', '3.95', '4.49', '1.70', '8.99', '2.00', '3.88',
#        '25.99', '399.99', '17.99', '400.00', '3.02', '1.76', '4.84',
#        '4.77', '1.61', '2.50', '1.59', '6.49', '1.29', '5.00', '13.99',
#        '299.99', '379.99', '37.99', '18.99', '389.99', '19.90', '8.49',
#        '1.75', '14.00', '4.85', '46.99', '109.99', '154.99', '3.08',
#        '2.59', '4.80', '1.96', '19.40', '3.90', '4.59', '15.46', '3.04',
#        '4.29', '2.60', '3.28', '4.60', '28.99', '2.95', '2.90', '1.97',
#        '200.00', '89.99', '2.56', '30.99', '3.61', '394.99', '1.26',
#        '1.20', '1.04'], dtype=object)

# %%
apps_data_copy['Installs'] = apps_data_copy['Installs'].astype('int')
apps_data_copy['Price'] = apps_data_copy['Price'].astype('float')
apps_data_copy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10840 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10840 non-null  object
#  1   Category        10840 non-null  object
#  2   Rating          9366 non-null   float64
#  3   Reviews         10840 non-null  int32
#  4   Size            9145 non-null   float64
#  5   Installs        10840 non-null  int32
#  6   Type            10839 non-null  object
#  7   Price           10840 non-null  float64
#  8   Content Rating  10840 non-null  object
#  9   Genres          10840 non-null  object
#  10  Last Updated    10840 non-null  object
#  11  Current Ver     10832 non-null  object
#  12  Android Ver     10838 non-null  object
# dtypes: float64(3), int32(2), object(8)
# memory usage: 1.1+ MB

# %% [markdown]
# ### 4.4] Last Updated

# %%
apps_data_copy['Last Updated'].unique()
# Out:
# array(['January 7, 2018', 'January 15, 2018', 'August 1, 2018', ...,
#        'January 20, 2014', 'February 16, 2014', 'March 23, 2014'],
#       dtype=object)

# %%
apps_data_copy['Last Updated'] = pd.to_datetime(apps_data_copy['Last Updated'])
apps_data_copy['Day'] = apps_data_copy['Last Updated'].dt.day
apps_data_copy['Month'] = apps_data_copy['Last Updated'].dt.month
apps_data_copy['Year'] = apps_data_copy['Last Updated'].dt.year

# %% [markdown]
# <div style="text-align: center; background-color: yellow; padding: 10px;">
#     <h2 style="font-weight: bold;">SAVING DATAFRAME TO CSV FILE</h2>
# </div>

# %%
apps_data_copy.to_csv('file2_googleplaystore_cleaned.csv', index = False)
